# %%
var=2
while(var!=5):
  print("selecciona una opcion:/N 1.suma/n2.resta/n3.multiplicacion/n4.division/nonlocal5.salir")
  var1=int(input("dame un numero:"))
  var2=int(input("dame otro numero:"))
  print(var1+var2)
